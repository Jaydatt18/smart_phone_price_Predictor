# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('smartphone.csv')

# %% [markdown]
# # Data Assessing MANUALLY
#
# # Quality Issues
#
#
# 1.   **model** :- some brands are written differently like OPPO in model column `consitency`
#
# 2. **price** - has unneccesary '₹' `validity` :-
#
# 3. **price** - phone Namotel has a price of 99 `accuracy` :- ** no in data**
#
# 4. ratings - missing values `completeness`
#
# 5. ratings - missing values `completeness`
#
# 6. processor - has some incorrect values for some samsung phones(row # -
# 318 , 369 , 398,422 , 443 , 455 , 474 , 486 , 492 , 503 , 539 , 559 , 584 , 623 , 637 , 643 , 646 , 647 , 664 , 666 , 689 , 694 , 700 , 703 , 704 , 713 , 725 , 726 , 738 , 750 , 765 , 767 , 794 , 806 , 807 , 816 , 818 , 819 , 827 , 831 , 840 , 869 , 880 , 886 , 893 , 907 , 912 , 913 , 919 , 927 , 928 , 930 , 933 , 939 , 939 , 942 , 944 , 950 , 956 , 975 , 976 , 979 , 990 , 993 , 998 , 999 , 1000 , 1001 , 1018
# )
#
# 7. There is ipod on row 756 `validity` :- **no in data**
#
# 8. **memory** - incorrect values in rows (
#
# 261 :- only rom is given
#
# 318 :- battery specification is given
#
# 398 :- mobile processor is given
#
# 422 :- mobile processor is given
#
# 425 :- battery specification is given
#
# 443 :- battery specification is given
#
# 472 :- only rom is given
#
# 474 :- only rom is given
#
# 486 :- only rom is given
#
# 492 :- mobile processor is given
#
# 503 :- mobile processor is given
#
# 539 :- memory is not given
#
# 559 :- mobile processor is given
#
# 584 :- wifi specification is  given
#
# 596 :- display specification is given
#
# 597 :- display specification is given
#
# 608 :- wifi specification is  given
#
# 609 :- display specification is given
#
# 623 :- mobile processor is given
#
# 637 :- mobile processor is given
#
# 643 :- mobile processor is given
#
# 644 :- only ram is given
#
# 646 :- mobile processor is given
#
# 647 :- mobile processor is given
#
# 664 :- mobile processor is given
#
# 666 :- mobile processor is given
#
# 664 :- battery specification is given
#
# 689:- battery specification is given
#
# 694 :- no wifi is given
#
# 700 :- battery specification is given
#
# 703 :- battery specification is given
#
# 704 :- battery specification is given
#
# 715 :- mobile processor is given
#
# 725 :- mobile processor is given
#
# 726 :- mobile processor is given
#
# 730 :- only rom is given
#
# 738 :- no wifi specification is given
#
# 765 :- mobile processor is given
#
# 767 :- mobile processor is given
#
# 794 :- battery specification is given
#
# 818 :- battery specification is given
#
# 819 :- battery specification is given
#
# 840 :- battery specification is given
#
# 869 :- battery specification is given
#
# 880 :- processor specification is given
#
#
# 886 :- battery specification is given
#
# 907 :- battery specification is given
#
# 912 :- battery specification is given
#
# 913 :- battery specification is given
#
# 919 :- battery specification is given
#
# 927 :- battery specification is given
#
# 928 :- battery specification is given
#
# 930 :- battery specification is given
#
# 933 :- battery specification is given
#
# 939 :- battery specification is given
#
# 942 :- battery specification is given
#
# 944 :- battery specification is given
#
# 956 :- battery specification is given
#
# 979 :- battery specification is given
#
# 990 :- battery specification is given
#
# 993 :- battery specification is given
#
# 999 :- ASR specification is given
#
# 1001 :- battery specification is given
# ) `validity`
#
#
#
# 9. **battery** - incorrect values in rows(
#   318 :- display specification  given
#
#   398 :- memory specification given
#
#   425 :- display specification  given
#
#   443 :- display specification  given
#
#   455 :- camera specification  given
#
#   474 :- display specification given
#
#   486 :- display specification  given
#
#   492 :- memory specification given
#
#   503 :- memory specification given
#
#   559 :- memory specification given
#
#   584 :- processor specification given
#
#   597 :- camera specification given
#
#   608 :- processor specification given
#
#   623 :- memory specification given
#
#   637 :- memory specification given
#
#   643 :- memory specification given
#
#   646 :- memory specification given
#
#   647 :- memory specification given
#
#   664 :- memory specification given
#
#   666 :- memory specification given
#
#   672 :- display specification  given
#
#   689 :- display specification  given
#
#   694 :- processor specification  given
#
#
#   703 :- display specification  given
#
#   704 :- display specification  given
#
#   715 :- memory specification  given
#
#   725 :- memory specification  given
#
#   726 :- memory specification  given
#
#   738 :- processor specification  given
#
#   765 :- memory specification  given
#
#   767 :- memory specification  given
#
#   794 :- memory specification  given
#
#   816 :- camera specification is given
#
#   818 :- display specification  given
#
#   819 :- display specification  given
#
#   831 :- display specification  given
#
#   840 :- display specification  given
#
#   886 :- display specification  given
#
#   893 :- camera specification given
#
#
#   907 :- display specification  given
#
#   912 :- display specification  given
#
#   913 :- display specification  given
#
#   919 :- display specification  given
#
#
#   927 :- display specification  given
#
#   928 :- display specification  given
#
#   930 :- display specification  given
#
#   933 :- display specification  given
#
#   939 :- display specification  given
#
#   942 :- display specification  given
#
#   944 :- display specification  given
#
#   956 :- display specification  given
#
#   969 :- display specification  given
#
#   979 :- display specification  given
#
#   990 :- display specification  given
#
#   993 :- processor specification  given
#
#   1001 :- display specification  given
#
#
# ) `validity`
#
#
# 10. **display** - sometimes frequency is not available `completeness`
#
# 11. **display** - incorrect values in rows(
#    318 :- camera specification given
#
#   398 :- battery specification given
#
#   425 :- camera specification given
#
#   443 :- camera specification given
#
#   455 :- memory specification given
#
#   474 :- camera specification given
#
#   486 :- camera specification given
#
#   492 :- battery specification given
#
#   503 :- battery specification given
#
#   559 :-  battery specification given
#
#   584 :-  battery specification given
#
#   596 :-  memory specification given
#
#   597 :-  memory specification given
#
#   608 :- battery specification given
#
#   609 :- memory specification given
#
#   623 :-  battery specification given
#
#   643 :-  battery specification given
#
#   646 :-  battery specification given
#
#   647 :-  battery specification given
#
#   664 :-  battery specification given
#
#   672 :-  camera specification given
#
#   689 :-  camera specification given
#
#   694 :-  memory specification given
#
#   700 :-  camera specification given
#
#   703 :-  camera specification given
#
#   704 :-  camera specification given
#
#   715 :-  battery specification given
#
#   725 :-  battery specification given
#
#   726 :-  battery specification given
#
#   738 :- memory specification given
#
#   765 :- memory specification given
#
#   767 :- memory specification given
#
#   794 :- memory specification given
#
#   816 :-  memory specification given
#
#   818 :-  memory specification given
#
#   819 :-  memory specification given
#
#   831 :-  camera specification given
#
#   840 :-  camera specification given
#
#   869 :-  camera specification given
#
#   880 :-  battery specification given
#
#   886 :-  camera specification given
#
#   893 :-  memory specification given
#
#   907 :- camera specification given
#
#   912 :- camera specification given
#
#   913 :- camera specification given
#
#   919 :-  camera specification given
#
#   927 :-  camera specification given
#
#   928 :-  camera specification given
#
#   930 :-  camera specification given
#
#   939 :-  camera specification given
#
#   942 :- camera specification given
#
#   944 :- camera specification given
#
#   956 :- camera specification given
#
#   969 :- camera specification given
#
#   979 :- camera specification given
#
#   990 :- camera specification given
#
#   993 :- memory specification given
#
#   999 :- memory specification given
#
#   1001 :- memory specification given
#
# )
#  `validity`
#
# 12. certain phones are foldable and the info is scattered `validity`
#
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
#
# 14. **camera** - problem with rows (
#   180 :- display specification given
#
#   318 :- memory specification given
#
#   361 :- display specification given
#
#   370  :- display specification given
#
#   373  :- display specification given
#
#   398  :- display specification given
#
#   406  :- display specification given
#
#   425  :- display specification given
#
#   431  :- display specification given
#
#   443  :- display specification given
#
#   370  :- card specification given
#
#   479  :- display specification given
#
#   474  :- display specification given
#
#   492  :- display specification given
#
#   503  :- display specification given
#
#   525  :- display specification given
#
#   559  :- display specification given
#
#   584  :- battery specification given
#
#   594  :- display specification given
#
#   596  :- os specification given
#
#   597  :- os specification given
#
#   605 :- card specification given
#
#   609  :- os specification given
#
#   686  :- card specification given
#
#   694  :- battery specification given
#
#   699  :- display specification given
#
#   700  :- display specification given
#
#   702  :- display specification given
#
#   704  :- display specification given
#
#   784  :- display specification given
#
#   794  :- card specification given
#
#   802  :- display specification given
#
#   803  :- display specification given
#
#   804  :- display specification given
#
#   805  :- display specification given
#
#   807  :- memory specification given
#
#   809  :- display specification given
#
#   816  :- os specification given
#
#   818  :- card specification given
#
#   819  :- card specification given
#
#   827  :- display specification given
#
#   831  :- card specification given
#
#   849  :- display specification given
#
#   869  :- card specification given
#
#   880  :- display specification given
#
#   886  :- OS  specification given
#
#   893 :- WORD nucleus
#
#   907 :- os specification given
#
#   912 :- card specification given
#
#   913 :- card specification given
#
#   919 :- card specification given
#
#   926 :- card specification given
#
#   927 :- card specification given
#
#   928 :- card specification given
#
#   930 :- card specification given
#
#   939 :- WORD S30+
#
#   942 :- CARD specification given
#
#   956 :- CARD specification given
#
#   975 :- card specification given
#
#   985 :- display specification given
#
#   986 :- display specification given
#
#   990 :- card specification given
#
#   993 :- card specification given
#
#   999 :- display specification given
#
#   1001 :- card specification given
#
#   1002 :- display specification given
#
#   1009 :- display specification given
#
#   1010 :- display specification given
#
#   1011 :- display specification given
#
# ) `validity`
#
#
# 12. certain phones are foldable and the info is scattered `validity`
#
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
#
# 15. **card** - sometimes contains info about os and camera `validity`
# (
#
# )
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
#
# 17. **os** - issue with rows (324,378) `validity`
#
# 18. **os** - sometimes contains os version name like lollipop `consistency`
#
# 19. missing values in camera, card and os `completeness`
#
# 20. datatype  of price and rating is incorrect `validity`
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
#
# 2. **ram** - can be split into 2 cols RAM and ROM
#
# 3. **processor** - can be split into processor name, cores and cpu speed.
#
# 4. **battery** - can be split into battery capacity, fast_charging_available
#
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
#
# 6. **camera** - can be split into front and rear camera
#
# 7. **card** - can be split into supported, extended_upto

# %%
df.rename(columns={'Unnamed: 0' : 'index'} , inplace = True)

# %%
df['index'] = df['index'] + 2

# %% [markdown]
# # CLEANING START

# %%
df
# Out:
#       index                       model    price  rating  \
# 0         2          Oppo K13 Turbo Pro  ₹37,999     NaN
# 1         3                 Vivo V60 5G  ₹36,999     NaN
# 2         4            Realme P4 Pro 5G  ₹24,999    73.0
# 3         5          Lava Play Ultra 5G  ₹14,999    79.0
# 4         6                Realme P4 5G  ₹18,499    77.0
# ...     ...                         ...      ...     ...
# 1014   1016       Samsung Galaxy F34 5G  ₹19,999     NaN
# 1015   1017                    Vivo Y18  ₹10,599    70.0
# 1016   1018              Nokia 105 2023     ₹899     NaN
# 1017   1019         OPPO Reno 11 Pro 5G  ₹30,900     NaN
# 1018   1020  Poco F5 (12GB RAM + 256GB)  ₹33,999     NaN
#
#                                                     sim  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# ...

# %% [markdown]
# # MAKING DUPLICATES

# %%
df1 = df.copy()

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # REPLCAING PRICE COLUMN OBJECT TO INTEGER

# %%
df1['price'] = df1['price'].str.replace('₹' , '').str.replace(',' , '').astype('int32')

# %% [markdown]
# # PROBLEMS WITH THE ROWS

# %%
processor_problem = set((318 , 369 , 398,422 , 443 , 455 , 474 , 486 , 492 , 503 , 539 , 559 , 584 , 623 , 637 ,
                         643 , 646 , 647 , 664 , 666 , 689 , 694 , 700 , 703 , 704 ,
                         713 , 725 , 726 , 738 , 750 , 765 , 767 , 794 , 806 , 807 , 816 ,
                         818 , 819 , 827 , 831 , 840 , 869 , 880 , 886 , 893 , 907 , 912 , 913 ,
                         919 , 927 , 928 , 930 , 933 , 939 , 939 , 942 , 944 , 950 , 956 , 975 , 976 ,
                         979 , 990 , 993 , 998 , 999 , 1000 , 1001 , 1018))

memory_problems = set((261, 318, 398, 422, 425, 443, 472, 474, 486, 492, 503, 539, 559, 584, 596, 597,
608, 609, 623, 637, 643, 644, 646, 647, 664, 666, 664, 689, 694, 700, 703, 704,
715, 725, 726, 730, 738, 765, 767, 794, 818, 819, 840, 869, 880, 886, 907, 912,
913, 919, 927, 928, 930, 933, 939, 942, 944, 956, 979, 990, 993, 999, 1001
))

battery_problem = set((318, 398, 425, 443, 455, 474, 486, 492, 503, 559, 584, 597, 608, 623, 637, 643,
646, 647, 664, 666, 672, 689, 694, 703, 704, 715, 725, 726, 738, 765, 767, 794,
816, 818, 819, 831, 840, 886, 893, 907, 912, 913, 919, 927, 928, 930, 933, 939,
942, 944, 956, 969, 979, 990, 993, 1001
))

display_problem = set((318, 398, 425, 443, 455, 474, 486, 492, 503, 559, 584, 596, 597, 608, 609, 623,
643, 646, 647, 664, 672, 689, 694, 700, 703, 704, 715, 725, 726, 738, 765, 767,
794, 816, 818, 819, 831, 840, 869, 880, 886, 893, 907, 912, 913, 919, 927, 928,
930, 939, 942, 944, 956, 969, 979, 990, 993, 999, 1001))

camera_problem = set((180, 318, 361, 370, 373, 398, 406, 425, 431, 443, 370, 479, 474, 492, 503, 525,
559, 584, 594, 596, 597, 605, 609, 686, 694, 699, 700, 702, 704, 784, 794, 802,
803, 804, 805, 807, 809, 816, 818, 819, 827, 831, 849, 869, 880, 886, 893, 907,
912, 913, 919, 926, 927, 928, 930, 939, 942, 956, 975, 985, 986, 990, 993, 999,
1001, 1002, 1009, 1010, 1011
))



# AFTER APPLYSING SEE THE ALL THE ROW ARE SHIFTED TO NEXT ROW BECAUSE SO ROWS ARE CONTAINING FEATURE PHONE
# WHICH IS NOT THE PART OF THE SMARTPHONE DATA
# SO WE DELETE THEM AND REMAINING WE ANALYZE
df1[df1['index'].isin(processor_problem & memory_problems & display_problem & camera_problem)]
# Out:
#      index                    model  price  rating  \
# 316    318            Lava A1 Music   1069     NaN
# 396    398        Nokia 235 4G 2024   3885     NaN
# 441    443       Motorola Moto A200   1099     NaN
# 472    474  Jio JioPhone Prima 2 4G   2799     NaN
# 490    492      Nokia 220 4G (2024)   3149     NaN
# 501    503     Nokia 3210 4G (2024)   3279     NaN
# 557    559          Nokia 2660 Flip   4499     NaN
# 582    584          itel IT5608 Neo   1390     NaN
# 692    694         Karbonn K160 Pop    941     NaN
# 698    700               Amaq Q1 4G   2499     NaN
# 702    704    Jio Bharat Karbonn K2    918     NaN
# 792    794                  Vox V20    849     NaN
# 816    818       Motorola Moto A10V   1298     NaN
# 817    819       Motorola Moto A50V   1399     NaN
# 867    869              Itel it5262   1289     NaN
# 878    880           GFive Rose 314    582     NaN
# 884    886           Karbonn ‎KX11I    890     NaN
# ...

# %%
# In smart_phone data some feature phones are in dataset , so we remove them
df1 = df1[df1['price'] >= 3885]

# %%
# processor_problem
df1[df1['index'].isin((318 , 369 , 398,422 , 443 , 455 , 474 , 486 , 492 , 503 , 539 , 559 , 584 , 623 , 637 , 643 , 646 , 647 , 664 , 666 , 689 , 694 , 700 , 703 , 704 , 713 , 725 , 726 , 738 , 750 , 765 , 767 , 794 , 806 , 807 , 816 , 818 , 819 , 827 , 831 , 840 , 869 , 880 , 886 , 893 ,
                       907 , 912 , 913 , 919 , 927 , 928 , 930 , 933 ,
                       939 , 939 , 942 , 944 , 950 , 956 , 975 , 976 , 979 , 990 , 993 ,
                       998 , 999 , 1000 , 1001 , 1018))]


df.drop([396 , 557 , 763 , 825] , inplace=True)

# %%
# battery
#
df1[df1['index'].isin(battery_problem)]
# Out:
#      index              model  price  rating                      sim  \
# 396    398  Nokia 235 4G 2024   3885     NaN  Dual Sim, 3G, 4G, VoLTE
# 557    559    Nokia 2660 Flip   4499     NaN         Dual Sim, 3G, 4G
# 763    765    HMD Barbie Flip   7999     NaN         Dual Sim, 3G, 4G
#
#     processor                           ram                    battery  \
# 396   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
# 557   No Wifi                   Unisoc T107  48 MB RAM, 128 MB inbuilt
# 763   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
#
#               display                            camera              card  \
# 396  1450 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
# 557  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
# 763  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
#
#                         os
# 396  Memory Card Supported
# 557     0.3 MP Rear Camera
# ...

# %%
df1[df1['index'].isin(battery_problem)]
# Out:
#      index              model  price  rating                      sim  \
# 396    398  Nokia 235 4G 2024   3885     NaN  Dual Sim, 3G, 4G, VoLTE
# 557    559    Nokia 2660 Flip   4499     NaN         Dual Sim, 3G, 4G
# 763    765    HMD Barbie Flip   7999     NaN         Dual Sim, 3G, 4G
#
#     processor                           ram                    battery  \
# 396   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
# 557   No Wifi                   Unisoc T107  48 MB RAM, 128 MB inbuilt
# 763   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
#
#               display                            camera              card  \
# 396  1450 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
# 557  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
# 763  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
#
#                         os
# 396  Memory Card Supported
# 557     0.3 MP Rear Camera
# ...

# %%
#display problem
df1[df1['index'].isin(display_problem)]
# Out:
#      index              model  price  rating                      sim  \
# 396    398  Nokia 235 4G 2024   3885     NaN  Dual Sim, 3G, 4G, VoLTE
# 557    559    Nokia 2660 Flip   4499     NaN         Dual Sim, 3G, 4G
# 763    765    HMD Barbie Flip   7999     NaN         Dual Sim, 3G, 4G
#
#     processor                           ram                    battery  \
# 396   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
# 557   No Wifi                   Unisoc T107  48 MB RAM, 128 MB inbuilt
# 763   No Wifi  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
#
#               display                            camera              card  \
# 396  1450 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
# 557  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
# 763  1450 mAh Battery  2.8 inches, 240 x 320 px Display      Dual Display
#
#                         os
# 396  Memory Card Supported
# 557     0.3 MP Rear Camera
# ...

# %%
df1[df1['index'].isin((180, 318, 361, 370, 373, 398, 406, 425, 431, 443, 370, 479, 474, 492, 503, 525,
559, 584, 594, 596, 597, 605, 609, 686, 694, 699, 700, 702, 704, 784, 794, 802,
803, 804, 805, 807, 809, 816, 818, 819, 827, 831, 849, 869, 880, 886, 893, 907,
912, 913, 919, 926, 927, 928, 930, 939, 942, 956, 975, 985, 986, 990, 993, 999,
1001, 1002, 1009, 1010, 1011))]
# Out:
#       index                                         model   price  rating  \
# 178     180                       Samsung Galaxy Z Fold 7  174999     NaN
# 359     361                        Motorola Razr 60 Ultra   89998     NaN
# 368     370              Lava Agni 3 5G (8GB RAM + 256GB)   19999     NaN
# 371     373                              Vivo X Fold 5 5G  149999     NaN
# 396     398                             Nokia 235 4G 2024    3885     NaN
# 404     406                       Samsung Galaxy Z Fold 6  122999     NaN
# 429     431    Samsung Galaxy Z Fold 7 (12GB RAM + 512GB)  186999     NaN
# 477     479           Realme 13 Plus 5G (8GB RAM + 256GB)   19369     NaN
# 523     525                             Vivo X Fold 3 Pro  159999     NaN
# 557     559                               Nokia 2660 Flip    4499     NaN
# 592     594  Samsung Galaxy Z Flip 7 FE (8GB RAM + 256GB)   78398     NaN
# 697     699              Lava Blaze Duo (8GB RAM + 128GB)   17999    79.0
# ...

# %%
df1.shape
# Out:
# (856, 12)

# %% [markdown]
# # AFTER ANALYZE
# **I FOUND BELOW 4499 NO SMARTPHONE **

# %%
df1 = df1[df1['price'] >= 4499]

# %%
df1[df1['processor'] == 'No Wifi']
# Out:
#      index            model  price  rating               sim processor  \
# 557    559  Nokia 2660 Flip   4499     NaN  Dual Sim, 3G, 4G   No Wifi
# 763    765  HMD Barbie Flip   7999     NaN  Dual Sim, 3G, 4G   No Wifi
#
#                               ram                    battery  \
# 557                   Unisoc T107  48 MB RAM, 128 MB inbuilt
# 763  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
#
#               display                            camera          card  \
# 557  1450 mAh Battery  2.8 inches, 240 x 320 px Display  Dual Display
# 763  1450 mAh Battery  2.8 inches, 240 x 320 px Display  Dual Display
#
#                      os
# 557  0.3 MP Rear Camera
# 763  0.3 MP Rear Camera

# %%
df1[df1['model'] == 'HMD Barbie Flip']
# Out:
#      index            model  price  rating               sim processor  \
# 763    765  HMD Barbie Flip   7999     NaN  Dual Sim, 3G, 4G   No Wifi
#
#                               ram                    battery  \
# 763  Unisoc T107, 1 GHz Processor  64 MB RAM, 128 MB inbuilt
#
#               display                            camera          card  \
# 763  1450 mAh Battery  2.8 inches, 240 x 320 px Display  Dual Display
#
#                      os
# 763  0.3 MP Rear Camera

# %%
df1.drop([557 , 763] , inplace = True)

# %% [markdown]
# # PROBLEM WITH PROCESSOR COLUMN
#
# *   NO PROBLEM WITH PROCESSOR COLUMN

# %%
# processor
df1[df1.index.isin([318 , 369 , 398,422 , 443 , 455 , 474 , 486 , 492 , 503 , 539 , 559 , 584 , 623 , 637 ,
                         643 , 646 , 647 , 664 , 666 , 689 , 694 , 700 , 703 , 704 ,
                         713 , 725 , 726 , 738 , 750 , 765 , 767 , 794 , 806 , 807 , 816 ,
                         818 , 819 , 827 , 831 , 840 , 869 , 880 , 886 , 893 , 907 , 912 , 913 ,
                         919 , 927 , 928 , 930 , 933 , 939 , 939 , 942 , 944 , 950 , 956 , 975 , 976 ,
                         979 , 990 , 993 , 998 , 999 , 1000 , 1001 , 1018])]
# Out:
#       index                                              model   price  \
# 318     320                     Realme 15 5G (8GB RAM + 256GB)   27999
# 369     371  Samsung Galaxy M15 5G Prime Edition (6GB RAM +...   15998
# 398     400           Samsung Galaxy A55 5G (12GB RAM + 256GB)   33999
# 422     424                  Infinix GT 30 5G (8GB RAM+ 256GB)   20999
# 443     445                   Oppo A5 Pro 5G (8GB RAM + 256GB)   19998
# 455     457            Samsung Galaxy A56 5G (8GB RAM + 256GB)   41999
# 474     476                            Apple iPhone 16 (512GB)   99900
# 486     488            Samsung Galaxy M35 5G (8GB RAM + 128GB)   18499
# 492     494               Tecno Camon 30 5G (12GB RAM + 512GB)   23999
# 503     505                 Nothing Phone 2a (8GB RAM + 256GB)   21695
# 539     541                                       OPPO Reno 11   25600
# 559     561                               Apple iPhone 14 Plus   69900
# ...

# %%
df1.rename(columns={'index' : 'index1'} , inplace=True)

# %%
df1[df1['index1'].isin([318 , 369 , 398,422 , 443 , 455 , 474 , 486 , 492 , 503 , 539 , 559 , 584 , 623 , 637 ,
                         643 , 646 , 647 , 664 , 666 , 689 , 694 , 700 , 703 , 704 ,
                         713 , 725 , 726 , 738 , 750 , 765 , 767 , 794 , 806 , 807 , 816 ,
                         818 , 819 , 827 , 831 , 840 , 869 , 880 , 886 , 893 , 907 , 912 , 913 ,
                         919 , 927 , 928 , 930 , 933 , 939 , 939 , 942 , 944 , 950 , 956 , 975 , 976 ,
                         979 , 990 , 993 , 998 , 999 , 1000 , 1001 , 1018])]
# Out:
# Empty DataFrame
# Columns: [index1, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %% [markdown]
# # ANALYZING COLUMN WITH VALUE_COUNTS() FUNCTION

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 6300, Octa Core, 2.4 GHz Processor         110
# Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor       25
# Dimensity 7300, Octa Core, 2.5 GHz Processor          24
# Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor     24
# Helio G85, Octa Core, 2 GHz Processor                 21
#                                                     ...
# Spreadtrum SC9863A1, Octa Core, 1.6 GHz Processor      1
# Snapdragon 8 Gen 2, Octa Core, 3.2 GHz Processor       1
# Exynos 1280 , Octa Core, 2.4 GHz Processor             1
# Dimensity 8050, Octa Core, 3 GHz Processor             1
# Snapdragon 7+ Gen2, Octa Core, 2.91 GHz Processor      1
# Name: count, Length: 165, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     194
# 8 GB RAM, 256 GB inbuilt     166
# 6 GB RAM, 128 GB inbuilt     117
# 12 GB RAM, 256 GB inbuilt    107
# 4 GB RAM, 128 GB inbuilt      85
# 4 GB RAM, 64 GB inbuilt       62
# 12 GB RAM, 512 GB inbuilt     47
# 16 GB RAM, 512 GB inbuilt     21
# 3 GB RAM, 64 GB inbuilt       12
# 16 GB RAM, 256 GB inbuilt      7
# 8 GB RAM, 512 GB inbuilt       7
# 12 GB RAM, 1 TB inbuilt        4
# 12 GB RAM, 128 GB inbuilt      4
# 3 GB RAM, 32 GB inbuilt        4
# 8 GB RAM, 1 TB inbuilt         3
# 6 GB RAM, 256 GB inbuilt       2
# 16 GB RAM, 1 TB inbuilt        2
# 128 GB inbuilt                 1
# 24 GB RAM, 1 TB inbuilt        1
# 256 GB inbuilt                 1
# 6 GB RAM, 64 GB inbuilt        1
# 2 GB RAM, 16 GB inbuilt        1
# 512 GB inbuilt                 1
# 2 GB RAM, 32 GB inbuilt        1
# 6 GB RAM, 512 GB inbuilt       1
# Name: count, dtype: int64

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 45W Fast Charging     61
# 5000 mAh Battery with 18W Fast Charging     55
# 5000 mAh Battery with 33W Fast Charging     44
# 5000 mAh Battery with 25W Fast Charging     43
# 5000 mAh Battery with 15W Fast Charging     39
#                                             ..
# 4600 mAh Battery with 100W Fast Charging     1
# 5800 mAh Battery with 35W Fast Charging      1
# 3274 mAh Battery with Fast Charging          1
# 6000 mAh Battery                             1
# 4200 mAh Battery with 33W Fast Charging      1
# Name: count, Length: 150, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     194
# 8 GB RAM, 256 GB inbuilt     166
# 6 GB RAM, 128 GB inbuilt     117
# 12 GB RAM, 256 GB inbuilt    107
# 4 GB RAM, 128 GB inbuilt      85
# 4 GB RAM, 64 GB inbuilt       62
# 12 GB RAM, 512 GB inbuilt     47
# 16 GB RAM, 512 GB inbuilt     21
# 3 GB RAM, 64 GB inbuilt       12
# 16 GB RAM, 256 GB inbuilt      7
# 8 GB RAM, 512 GB inbuilt       7
# 12 GB RAM, 1 TB inbuilt        4
# 12 GB RAM, 128 GB inbuilt      4
# 3 GB RAM, 32 GB inbuilt        4
# 8 GB RAM, 1 TB inbuilt         3
# 6 GB RAM, 256 GB inbuilt       2
# 16 GB RAM, 1 TB inbuilt        2
# 128 GB inbuilt                 1
# 24 GB RAM, 1 TB inbuilt        1
# 256 GB inbuilt                 1
# 6 GB RAM, 64 GB inbuilt        1
# 2 GB RAM, 16 GB inbuilt        1
# 512 GB inbuilt                 1
# 2 GB RAM, 32 GB inbuilt        1
# 6 GB RAM, 512 GB inbuilt       1
# Name: count, dtype: int64

# %%
df1['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole        62
# 6.77 inches, 1080 x 2392 px, 120 Hz Display with Punch Hole        45
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole         40
# 6.67 inches, 720 x 1604 px, 120 Hz Display with Punch Hole         34
# 6.74 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch    24
#                                                                    ..
# 6.1 inches, 1179 x 2556 px, 120 Hz Display with Dynamic Island      1
# 6.72 inches, 1080 x 2400 px Display with Water Drop Notch           1
# 6.64 inches, 1080 x 2388 px Display with Water Drop Notch           1
# 6.9 inches, 1080 x 2640 px, 165 Hz Display with Punch Hole          1
# 6.9 inches, 1080 x 2640 px, 144 Hz Display with Punch Hole          1
# Name: count, Length: 177, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                73
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera               53
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera               31
# Foldable Display, Dual Display                            27
# 50 MP Dual Rear & 8 MP Front Camera                       23
#                                                           ..
# 48 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera     1
# 8 MP + 2 MP Dual Rear & 5 MP Front Camera                  1
# 50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera        1
# 50 MP + 0.08 MP Dual Rear & 16 MP Front Camera             1
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera          1
# Name: count, Length: 159, dtype: int64

# %%
temp_df = df1[df1['camera'] == 'Foldable Display, Dual Display']

# %%
temp_df = df1[df1['card'].str.contains('MP')]

# %%
df1.loc[temp_df.index , 'camera'] = temp_df['card'].values

# %%
temp_df = df1[df1['card'].str.contains('MP')]

# %%
df1.loc[temp_df.index , 'card'] = 'Memory Card Not Supported'

# %%
temp_df = df1[df1['card'].str.contains('Android')]

# %%
df1.loc[temp_df.index , 'os'] = temp_df['card']

# %%
temp_df = df1[df1['os'] == 'Memory Card Not Supported']

# %%
df1.loc[temp_df.index , 'os'] = np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v14            366
# Android v15            276
# Android v13            117
# Android v12             24
# iOS v18                 16
# Android v11             10
# Android v16              6
# iOS v17                  6
# Android v10              5
# iOS v16                  3
# iOS v15                  1
# Blackberry OS v10.3      1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns' , None)

# %%
temp_df = df1[df1['card'].str.contains('Android')]

# %%
df1.loc[temp_df.index , 'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             415
# Memory Card (Hybrid), upto 1 TB       132
# Memory Card Supported, upto 1 TB      110
# Memory Card (Hybrid), upto 2 TB        60
# Memory Card Supported, upto 2 TB       41
# Memory Card (Hybrid)                   38
# Memory Card Supported                  29
# Memory Card (Hybrid), upto 1.5 TB      11
# Memory Card Supported, upto 256 GB      8
# Memory Card Supported, upto 512 GB      7
# Memory Card (Hybrid), upto 256 GB       1
# Name: count, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera           73
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera          53
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera          31
# 50 MP Dual Rear & 8 MP Front Camera                  23
# 50 MP + 2 MP Dual Rear & 32 MP Front Camera          21
#                                                      ..
# 8 MP + 2 MP Dual Rear & 5 MP Front Camera             1
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera          1
# 50 MP + 0.08 MP Dual Rear & 16 MP Front Camera        1
# 64 MP + 13 MP Dual Rear & 32 MP Front Camera          1
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera     1
# Name: count, Length: 168, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera           73
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera          53
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera          31
# 50 MP Dual Rear & 8 MP Front Camera                  23
# 50 MP + 2 MP Dual Rear & 32 MP Front Camera          21
#                                                      ..
# 8 MP + 2 MP Dual Rear & 5 MP Front Camera             1
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera          1
# 50 MP + 0.08 MP Dual Rear & 16 MP Front Camera        1
# 64 MP + 13 MP Dual Rear & 32 MP Front Camera          1
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera     1
# Name: count, Length: 168, dtype: int64

# %%
df['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole        62
# 6.77 inches, 1080 x 2392 px, 120 Hz Display with Punch Hole        45
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole         40
# 6.67 inches, 720 x 1604 px, 120 Hz Display with Punch Hole         34
# 6.74 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch    24
#                                                                    ..
# 6.1 inches, 1179 x 2556 px, 120 Hz Display with Dynamic Island      1
# 6.72 inches, 1080 x 2400 px Display with Water Drop Notch           1
# 6.64 inches, 1080 x 2388 px Display with Water Drop Notch           1
# 6.9 inches, 1080 x 2640 px, 165 Hz Display with Punch Hole          1
# 6.9 inches, 1080 x 2640 px, 144 Hz Display with Punch Hole          1
# Name: count, Length: 240, dtype: int64

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 45W Fast Charging     61
# 5000 mAh Battery with 18W Fast Charging     55
# 5000 mAh Battery with 33W Fast Charging     44
# 5000 mAh Battery with 25W Fast Charging     43
# 5000 mAh Battery with 15W Fast Charging     39
#                                             ..
# 4600 mAh Battery with 100W Fast Charging     1
# 5800 mAh Battery with 35W Fast Charging      1
# 3274 mAh Battery with Fast Charging          1
# 6000 mAh Battery                             1
# 4200 mAh Battery with 33W Fast Charging      1
# Name: count, Length: 150, dtype: int64

# %%
df['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt      194
# 8 GB RAM, 256 GB inbuilt      166
# 6 GB RAM, 128 GB inbuilt      117
# 12 GB RAM, 256 GB inbuilt     107
# 4 GB RAM, 128 GB inbuilt       85
#                              ...
# 512 MB RAM, 512 MB inbuilt      1
# 6 GB RAM, 512 GB inbuilt        1
# 32 MB RAM, 600 MB inbuilt       1
# ASR                             1
# 4000 mAh Battery                1
# Name: count, Length: 77, dtype: int64

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 6300, Octa Core, 2.4 GHz Processor         110
# Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor       25
# Dimensity 7300, Octa Core, 2.5 GHz Processor          24
# Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor     24
# Helio G85, Octa Core, 2 GHz Processor                 21
#                                                     ...
# Spreadtrum SC9863A1, Octa Core, 1.6 GHz Processor      1
# Snapdragon 8 Gen 2, Octa Core, 3.2 GHz Processor       1
# Exynos 1280 , Octa Core, 2.4 GHz Processor             1
# Dimensity 8050, Octa Core, 3 GHz Processor             1
# Snapdragon 7+ Gen2, Octa Core, 2.91 GHz Processor      1
# Name: count, Length: 165, dtype: int64

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           281
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      151
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           97
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                                96
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                82
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                 61
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster     30
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                      24
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    14
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                            7
# Dual Sim, 3G, 4G, Wi-Fi                                        4
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           2
# Single Sim, 3G, 4G, Wi-Fi, HDMI                                1
# Single Sim, 3G, 4G, Wi-Fi                                      1
# ...

# %%
df1.to_csv('smart_phone_clean.csv')

# %%
df1
# Out:
#       index1                       model  price  rating  \
# 0          2          Oppo K13 Turbo Pro  37999     NaN
# 1          3                 Vivo V60 5G  36999     NaN
# 2          4            Realme P4 Pro 5G  24999    73.0
# 3          5          Lava Play Ultra 5G  14999    79.0
# 4          6                Realme P4 5G  18499    77.0
# ...      ...                         ...    ...     ...
# 1013    1015                   Vivo V29e  26999     NaN
# 1014    1016       Samsung Galaxy F34 5G  19999     NaN
# 1015    1017                    Vivo Y18  10599    70.0
# 1017    1019         OPPO Reno 11 Pro 5G  30900     NaN
# 1018    1020  Poco F5 (12GB RAM + 256GB)  33999     NaN
#
#                                                     sim  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# ...

# %%
df1.head()
# Out:
#    index1               model  price  rating  \
# 0       2  Oppo K13 Turbo Pro  37999     NaN
# 1       3         Vivo V60 5G  36999     NaN
# 2       4    Realme P4 Pro 5G  24999    73.0
# 3       5  Lava Play Ultra 5G  14999    79.0
# 4       6        Realme P4 5G  18499    77.0
#
#                                                  sim  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1    Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
# 2            Snapdragon 7 Gen 4, Octa Core Processor
# 3       Dimensity 7300, Octa Core, 2.5 GHz Processor
# 4  Dimensity 7400 Ultra, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
brand_names = df1['model'].str.split(' ').str.get(0)

# %%
brand_names
# Out:
# 0          Oppo
# 1          Vivo
# 2        Realme
# 3          Lava
# 4        Realme
#          ...
# 1013       Vivo
# 1014    Samsung
# 1015       Vivo
# 1017       OPPO
# 1018       Poco
# Name: model, Length: 852, dtype: object

# %%
df1.insert(1 , 'brand_name' , brand_names)

# %%
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
# 2       4     realme    Realme P4 Pro 5G  24999    73.0
# 3       5       lava  Lava Play Ultra 5G  14999    79.0
# 4       6     realme        Realme P4 5G  18499    77.0
#
#                                                  sim  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1    Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
# 2            Snapdragon 7 Gen 4, Octa Core Processor
# 3       Dimensity 7300, Octa Core, 2.5 GHz Processor
# ...

# %%
has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6 , 'has_5g' , has_5g)
df1.insert(7 , 'has_nfc' , has_nfc)
df1.insert(6 , 'has_ir_blaster' , has_ir_blaster)

# %%
df1
# Out:
#       index1 brand_name                       model  price  rating  \
# 0          2       oppo          Oppo K13 Turbo Pro  37999     NaN
# 1          3       vivo                 Vivo V60 5G  36999     NaN
# 2          4     realme            Realme P4 Pro 5G  24999    73.0
# 3          5       lava          Lava Play Ultra 5G  14999    79.0
# 4          6     realme                Realme P4 5G  18499    77.0
# ...      ...        ...                         ...    ...     ...
# 1013    1015       vivo                   Vivo V29e  26999     NaN
# 1014    1016    samsung       Samsung Galaxy F34 5G  19999     NaN
# 1015    1017       vivo                    Vivo Y18  10599    70.0
# 1017    1019       oppo         OPPO Reno 11 Pro 5G  30900     NaN
# 1018    1020       poco  Poco F5 (12GB RAM + 256GB)  33999     NaN
#
#                                                     sim  has_ir_blaster  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# ...

# %%
# processor
processor_names = df1['processor'].str.split(',').str.get(0)
num_cores = df1['processor'].str.split(',').str.get(1)
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10 , 'processor_name' , processor_names)
df1.insert(11 , 'num_cores' , num_cores)
df1.insert(12 , 'processor_speed' , processor_speed)

# %%
df1.head()
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
# 2       4     realme    Realme P4 Pro 5G  24999    73.0
# 3       5       lava  Lava Play Ultra 5G  14999    79.0
# 4       6     realme        Realme P4 5G  18499    77.0
#
#                                                  sim  has_ir_blaster  has_5g  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True    True
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 3           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi           False    True
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
#
#    has_nfc                                          processor  \
# 0    False   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# ...

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300         110
# Snapdragon 4 Gen2       25
# Dimensity 7300          24
# Dimensity 6100 Plus     24
# Helio G85               21
#                       ...
# Dimensity 1080           1
# Spreadtrum SC9863A1      1
# Exynos 1280              1
# Dimensity 8050           1
# Snapdragon 7+ Gen2       1
# Name: count, Length: 156, dtype: int64

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300         110
# Snapdragon 4 Gen2       25
# Dimensity 7300          24
# Dimensity 6100 Plus     24
# Helio G85               21
#                       ...
# Dimensity 1080           1
# Spreadtrum SC9863A1      1
# Exynos 1280              1
# Dimensity 8050           1
# Snapdragon 7+ Gen2       1
# Name: count, Length: 156, dtype: int64

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Dimensity 6300         110
# Snapdragon 4 Gen2       25
# Dimensity 7300          24
# Dimensity 6100 Plus     24
# Helio G85               21
#                       ...
# Dimensity 1080           1
# Spreadtrum SC9863A1      1
# Exynos 1280              1
# Dimensity 8050           1
# Snapdragon 7+ Gen2       1
# Name: count, Length: 156, dtype: int64

# %%
df1[df1['processor_name'].str.contains('Core')][['processor_name' , 'num_cores' , 'processor_speed']]
# Out:
#           processor_name           num_cores processor_speed
# 677            Octa Core   2.3 GHz Processor             NaN
# 682  Octa Core Processor                 NaN             NaN
# 689  Octa Core Processor                 NaN             NaN
# 695  Octa Core Processor                 NaN             NaN
# 857  Octa Core Processor                 NaN             NaN

# %%
df1[df1['processor_name'] == '(28 nm)']
# Out:
# Empty DataFrame
# Columns: [index1, brand_name, model, price, rating, sim, has_ir_blaster, has_5g, has_nfc, processor, processor_name, num_cores, processor_speed, ram, battery, display, camera, card, os]
# Index: []

# %%
processor_brd = df1['processor'].str.split(' ').str.get(0)

# %%
df1.insert(11 , 'processor_brand' , processor_brd)

# %%
df1
# Out:
#       index1 brand_name                       model  price  rating  \
# 0          2       oppo          Oppo K13 Turbo Pro  37999     NaN
# 1          3       vivo                 Vivo V60 5G  36999     NaN
# 2          4     realme            Realme P4 Pro 5G  24999    73.0
# 3          5       lava          Lava Play Ultra 5G  14999    79.0
# 4          6     realme                Realme P4 5G  18499    77.0
# ...      ...        ...                         ...    ...     ...
# 1013    1015       vivo                   Vivo V29e  26999     NaN
# 1014    1016    samsung       Samsung Galaxy F34 5G  19999     NaN
# 1015    1017       vivo                    Vivo Y18  10599    70.0
# 1017    1019       oppo         OPPO Reno 11 Pro 5G  30900     NaN
# 1018    1020       poco  Poco F5 (12GB RAM + 256GB)  33999     NaN
#
#                                                     sim  has_ir_blaster  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# ...

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              782
# Hexa Core               26
# Octa Core Processor     20
# Deca Core                9
# Nine-Cores               2
# Nine Cores               2
# Quad Core                2
# Nine Core                1
# 2.3 GHz Processor        1
# Name: count, dtype: int64

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1['num_cores'] == '2.3 GHz Processor'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1013    False
# 1014    False
# 1015    False
# 1017    False
# 1018    False
# Name: num_cores, Length: 852, dtype: bool

# %%
temp_df  = df1[df1['num_cores'] == '2.3 GHz Processor']

# %%
temp_df
# Out:
#      index1 brand_name                model  price  rating  \
# 677     679      bigme  Bigme Hibreak E INK  39490    64.0
#
#                            sim  has_ir_blaster  has_5g  has_nfc  \
# 677  Single Sim, 3G, 4G, Wi-Fi           False   False    False
#
#                         processor processor_name processor_brand  \
# 677  Octa Core, 2.3 GHz Processor      Octa Core            Octa
#
#              num_cores processor_speed                       ram  \
# 677  2.3 GHz Processor             NaN  6 GB RAM, 128 GB inbuilt
#
#               battery                             display  \
# 677  3300 mAh Battery  5.84 inches, 720 x 1440 px Display
#
#                              camera                              card  \
# 677  13 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 1 TB
#
#               os
# 677  Android v11

# %%
df1.loc[temp_df.index , 'processor_speed'] = temp_df['num_cores'].values

# %%
temp_df  = df1[df1['num_cores'] == '2.3 GHz Processor']

# %%
df1.loc[temp_df.index , 'num_cores'] = temp_df['num_cores'].values

# %%
df1['processor_brand'].value_counts()
# Out:
# processor_brand
# Dimensity     360
# Snapdragon    280
# Unisoc         59
# Exynos         49
# Helio          42
# Bionic         26
# Tensor         17
# Octa            5
# Google          4
# Tiger           3
# Dimensit        2
# unisoc          2
# UNISOC          1
# AMD,            1
# Spreadtrum      1
# Name: count, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     194
# 8 GB RAM, 256 GB inbuilt     166
# 6 GB RAM, 128 GB inbuilt     117
# 12 GB RAM, 256 GB inbuilt    107
# 4 GB RAM, 128 GB inbuilt      85
# 4 GB RAM, 64 GB inbuilt       62
# 12 GB RAM, 512 GB inbuilt     47
# 16 GB RAM, 512 GB inbuilt     21
# 3 GB RAM, 64 GB inbuilt       12
# 16 GB RAM, 256 GB inbuilt      7
# 8 GB RAM, 512 GB inbuilt       7
# 12 GB RAM, 1 TB inbuilt        4
# 12 GB RAM, 128 GB inbuilt      4
# 3 GB RAM, 32 GB inbuilt        4
# 8 GB RAM, 1 TB inbuilt         3
# 6 GB RAM, 256 GB inbuilt       2
# 16 GB RAM, 1 TB inbuilt        2
# 128 GB inbuilt                 1
# 24 GB RAM, 1 TB inbuilt        1
# 256 GB inbuilt                 1
# 6 GB RAM, 64 GB inbuilt        1
# 2 GB RAM, 16 GB inbuilt        1
# 512 GB inbuilt                 1
# 2 GB RAM, 32 GB inbuilt        1
# 6 GB RAM, 512 GB inbuilt       1
# Name: count, dtype: int64

# %%
ram_name = df1['ram'].str.split(',').str.get(0)

# %%
df1
# Out:
#       index1 brand_name                       model  price  rating  \
# 0          2       oppo          Oppo K13 Turbo Pro  37999     NaN
# 1          3       vivo                 Vivo V60 5G  36999     NaN
# 2          4     realme            Realme P4 Pro 5G  24999    73.0
# 3          5       lava          Lava Play Ultra 5G  14999    79.0
# 4          6     realme                Realme P4 5G  18499    77.0
# ...      ...        ...                         ...    ...     ...
# 1013    1015       vivo                   Vivo V29e  26999     NaN
# 1014    1016    samsung       Samsung Galaxy F34 5G  19999     NaN
# 1015    1017       vivo                    Vivo Y18  10599    70.0
# 1017    1019       oppo         OPPO Reno 11 Pro 5G  30900     NaN
# 1018    1020       poco  Poco F5 (12GB RAM + 256GB)  33999     NaN
#
#                                                     sim  has_ir_blaster  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# ...

# %%
df1.insert(15 , 'Ram' , ram_name)

# %%
memory = df1['ram'].str.split(',').str.get(1)

# %%
df1.insert(16 , 'storage' , memory)

# %%
s_battery = df1['battery'].str.split('with').str.get(0)

# %%
df1.insert(17 , 'battery_mAh' , s_battery)

# %%
wolt_fast_charning = df1['battery'].str.split('with').str.get(1)

# %%
df1.insert(18 , 'v_fast_charnging' , wolt_fast_charning)

# %%
display_siz  = df1['display'].str.split(',').str.get(0)

# %%
df1.insert(20 , 'display_size' , display_siz)

# %%
pxl = df1['display'].str.split(',').str.get(1)

# %%
df1.insert(21 , 'pixel_size' , pxl)

# %%
df1.head()
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
# 2       4     realme    Realme P4 Pro 5G  24999    73.0
# 3       5       lava  Lava Play Ultra 5G  14999    79.0
# 4       6     realme        Realme P4 5G  18499    77.0
#
#                                                  sim  has_ir_blaster  has_5g  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True    True
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 3           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi           False    True
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
#
#    has_nfc                                          processor  \
# 0    False   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# ...

# %%
ds_speed = df1['display'].str.split(',').str.get(2)

# %%
df1.insert(21, 'display_speed' , ds_speed)

# %%
df1.head(2)
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
#
#                                                  sim  has_ir_blaster  has_5g  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True    True
#
#    has_nfc                                         processor  \
# 0    False  Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1     True   Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
#
#        processor_name processor_brand  num_cores     processor_speed  \
# 0  Snapdragon 8s Gen4      Snapdragon  Octa Core   3.2 GHz Processor
# 1   Snapdragon 7 Gen4      Snapdragon  Octa Core   2.8 GHz Processor
#
#                         ram       Ram          storage        battery_mAh  \
# 0  8 GB RAM, 256 GB inbuilt  8 GB RAM   256 GB inbuilt  7000 mAh Battery
# ...

# %%
# camera

re_cmera = df1['camera'].str.split('&').str.get(0)

# %%
df1.insert(24 , 'rear_camera' , re_cmera)

# %%
df1.head(2)
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
#
#                                                  sim  has_ir_blaster  has_5g  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True    True
#
#    has_nfc                                         processor  \
# 0    False  Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1     True   Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
#
#        processor_name processor_brand  num_cores     processor_speed  \
# 0  Snapdragon 8s Gen4      Snapdragon  Octa Core   3.2 GHz Processor
# 1   Snapdragon 7 Gen4      Snapdragon  Octa Core   2.8 GHz Processor
#
#                         ram       Ram          storage        battery_mAh  \
# 0  8 GB RAM, 256 GB inbuilt  8 GB RAM   256 GB inbuilt  7000 mAh Battery
# ...

# %%
frnt_cmera = df1['camera'].str.split('&').str.get(1)

# %%
df1.insert(24 , 'front' , frnt_cmera)

# %%
df1.head(2)
# Out:
#    index1 brand_name               model  price  rating  \
# 0       2       oppo  Oppo K13 Turbo Pro  37999     NaN
# 1       3       vivo         Vivo V60 5G  36999     NaN
#
#                                                  sim  has_ir_blaster  has_5g  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True    True
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...            True    True
#
#    has_nfc                                         processor  \
# 0    False  Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1     True   Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
#
#        processor_name processor_brand  num_cores     processor_speed  \
# 0  Snapdragon 8s Gen4      Snapdragon  Octa Core   3.2 GHz Processor
# 1   Snapdragon 7 Gen4      Snapdragon  Octa Core   2.8 GHz Processor
#
#                         ram       Ram          storage        battery_mAh  \
# 0  8 GB RAM, 256 GB inbuilt  8 GB RAM   256 GB inbuilt  7000 mAh Battery
# ...

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             415
# Memory Card (Hybrid), upto 1 TB       132
# Memory Card Supported, upto 1 TB      110
# Memory Card (Hybrid), upto 2 TB        60
# Memory Card Supported, upto 2 TB       41
# Memory Card (Hybrid)                   38
# Memory Card Supported                  29
# Memory Card (Hybrid), upto 1.5 TB      11
# Memory Card Supported, upto 256 GB      8
# Memory Card Supported, upto 512 GB      7
# Memory Card (Hybrid), upto 256 GB       1
# Name: count, dtype: int64

# %%
df1['extended_memory'] = df1['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
df1
# Out:
#       index1 brand_name                       model  price  rating  \
# 0          2       oppo          Oppo K13 Turbo Pro  37999     NaN
# 1          3       vivo                 Vivo V60 5G  36999     NaN
# 2          4     realme            Realme P4 Pro 5G  24999    73.0
# 3          5       lava          Lava Play Ultra 5G  14999    79.0
# 4          6     realme                Realme P4 5G  18499    77.0
# ...      ...        ...                         ...    ...     ...
# 1013    1015       vivo                   Vivo V29e  26999     NaN
# 1014    1016    samsung       Samsung Galaxy F34 5G  19999     NaN
# 1015    1017       vivo                    Vivo Y18  10599    70.0
# 1017    1019       oppo         OPPO Reno 11 Pro 5G  30900     NaN
# 1018    1020       poco  Poco F5 (12GB RAM + 256GB)  33999     NaN
#
#                                                     sim  has_ir_blaster  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster            True
# ...

# %%
temp_df = df1[df1.os.isna()]

# %%
df1.loc[temp_df.index , 'os'] = 'not specified'

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Blackberry':
    return 'blackberry'

# %%
df1['os_system'] = df1['os'].apply(os_extractor)

# %%
df1['os_system'].value_counts()
# Out:
# os_system
# android       804
# ios            26
# blackberry     22
# Name: count, dtype: int64

# %%
df1['os_version'] = df1['os'].str.split(' ').str.get(1)

# %%
df1['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                       415
# 1 TB                    242
# 2 TB                    101
# Memory Card (Hybrid)     38
# Not Specified            29
# 1.5 TB                   11
# 256 GB                    9
# 512 GB                    7
# Name: count, dtype: int64

# %%
df2 = df1[['brand_name' , 'model' , 'price' , 'rating', 'has_ir_blaster' , 'has_5g' , 'has_nfc' , 'processor_name' , 'processor_brand' , 'num_cores' , 'processor_speed' , 'Ram' , 'storage' , 'battery_mAh' , 'v_fast_charnging' , 'display_size' , 'display_speed' , 'pixel_size' , 'front' , 'rear_camera' , 'extended_memory' , 'os_system' , 'os_version']]

# %%
# applying brand in lower case
df2['model'] = df2['model'].str.lower()
# Out:
# /tmp/ipython-input-2460341676.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['model'] = df2['model'].str.lower()

# %%
df2['price'].isna().sum()
# Out:
# np.int64(0)

# %%
df2['has_ir_blaster'] = df2['has_ir_blaster'].astype('bool')
# Out:
# /tmp/ipython-input-719436902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['has_ir_blaster'] = df2['has_ir_blaster'].astype('bool')

# %%
def change(text):
  if True :
    return 1
  elif False :
    return 0

# %%
df2['has_ir_blaster'] = df2['has_ir_blaster'].astype('int')
# Out:
# /tmp/ipython-input-757095313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['has_ir_blaster'] = df2['has_ir_blaster'].astype('int')

# %%
df2['has_5g'] = df2['has_5g'].astype('int')
# Out:
# /tmp/ipython-input-3497381515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['has_5g'] = df2['has_5g'].astype('int')

# %%
df2['has_nfc'] = df2['has_nfc'].astype('int')
# Out:
# /tmp/ipython-input-606033660.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['has_nfc'] = df2['has_nfc'].astype('int')

# %%
df2['processor_name'] = df2['processor_name'].str.lower()
# Out:
# /tmp/ipython-input-1419897248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_name'] = df2['processor_name'].str.lower()

# %%
df2['processor_brand'] = df2['processor_brand'].str.lower()
# Out:
# /tmp/ipython-input-3633095237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_brand'] = df2['processor_brand'].str.lower()

# %%
df2['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core              782
# Hexa Core               26
# Octa Core Processor     20
# Deca Core                9
# Nine-Cores               2
# Nine Cores               2
# Quad Core                2
# Nine Core                1
# 2.3 GHz Processor        1
# Name: count, dtype: int64

# %%
temp_df = df2[df2['num_cores'] == 'Octa Core Processor']

# %%
df2.loc[temp_df.index , 'num_cores'] = 'Octa Core'

# %%
df2['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core            802
# Hexa Core             26
# Deca Core              9
# Nine-Cores             2
# Nine Cores             2
# Quad Core              2
# Nine Core              1
# 2.3 GHz Processor      1
# Name: count, dtype: int64

# %%
temp_df = df2[df2['num_cores'] == '2.3 GHz Processor']

# %%
df2.loc[temp_df.index , 'processor_name'] = 'MediaTek Helio P35'

# %%
df2['processor_name'] == 'MediaTek Helio P35'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1013    False
# 1014    False
# 1015    False
# 1017    False
# 1018    False
# Name: processor_name, Length: 852, dtype: bool

# %%
df2['processor_name'] = df2['processor_name'].str.lower()
# Out:
# /tmp/ipython-input-1419897248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_name'] = df2['processor_name'].str.lower()

# %%
df2.head()
# Out:
#   brand_name               model  price  rating  has_ir_blaster  has_5g  \
# 0       oppo  oppo k13 turbo pro  37999     NaN               1       1
# 1       vivo         vivo v60 5g  36999     NaN               1       1
# 2     realme    realme p4 pro 5g  24999    73.0               1       1
# 3       lava  lava play ultra 5g  14999    79.0               0       1
# 4     realme        realme p4 5g  18499    77.0               1       1
#
#    has_nfc        processor_name processor_brand  num_cores  \
# 0        0    snapdragon 8s gen4      snapdragon  Octa Core
# 1        1     snapdragon 7 gen4      snapdragon  Octa Core
# 2        0    snapdragon 7 gen 4      snapdragon  Octa Core
# 3        0        dimensity 7300       dimensity  Octa Core
# 4        0  dimensity 7400 ultra       dimensity  Octa Core
#
#       processor_speed       Ram          storage        battery_mAh  \
# 0   3.2 GHz Processor  8 GB RAM   256 GB inbuilt  7000 mAh Battery
# ...

# %%
df2.loc[temp_df.index , 'processor_brand'] = 'mediaTek'

# %%
df2[df2['num_cores'] == '2.3 GHz Processor']
# Out:
#     brand_name                model  price  rating  has_ir_blaster  has_5g  \
# 677      bigme  bigme hibreak e ink  39490    64.0               0       0
#
#      has_nfc      processor_name processor_brand          num_cores  \
# 677        0  mediatek helio p35        mediaTek  2.3 GHz Processor
#
#        processor_speed       Ram          storage       battery_mAh  \
# 677  2.3 GHz Processor  6 GB RAM   128 GB inbuilt  3300 mAh Battery
#
#     v_fast_charnging display_size display_speed              pixel_size  \
# 677              NaN  5.84 inches           NaN   720 x 1440 px Display
#
#                   front  rear_camera extended_memory os_system os_version
# 677   5 MP Front Camera  13 MP Rear             1 TB   android        v11

# %%
df2.loc[temp_df.index , 'num_cores'] = 'Octa Core'

# %%
df2['num_cores'] = df2['num_cores'].str.lower()
# Out:
# /tmp/ipython-input-737019909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['num_cores'] = df2['num_cores'].str.lower()

# %%
temp_df = df2[df2['model'] == 'google pixel 10 pro']
df2.loc[temp_df.index , 'num_cores'] = 'octa core'
df2[df2['model'] == 'google pixel 10 pro']
# Out:
#    brand_name                model   price  rating  has_ir_blaster  has_5g  \
# 28     google  google pixel 10 pro  109999     NaN               0       1
#
#     has_nfc processor_name processor_brand  num_cores processor_speed  \
# 28        1      tensor g5          tensor  octa core             NaN
#
#           Ram          storage        battery_mAh    v_fast_charnging  \
# 28  16 GB RAM   256 GB inbuilt  4870 mAh Battery    30W Fast Charging
#
#    display_size                    display_speed       pixel_size  \
# 28   6.3 inches   120 Hz Display with Punch Hole   1280 x 2856 px
#
#                   front                         rear_camera extended_memory  \
# 28   42 MP Front Camera  50 MP + 48 MP + 48 MP Triple Rear                0
#
#    os_system os_version
# 28   android        v16

# %%
df2[df2['num_cores'].isna()]
temp_df = df2[df2['model'] == 'google pixel 10']
df2.loc[temp_df.index , 'num_cores'] = 'octa core'

# %%
df2[df2['num_cores'].isna()]
temp_df = df2[df2['model'] == 'google pixel 10 pro xl']
df2.loc[temp_df.index , 'num_cores'] = 'multi core'

# %%
temp_df = df2[df2['model'] == 'itel zeno 10 (4gb ram + 64gb)']
df2.loc[temp_df.index , 'processor_name'] = 'unisoc t603'

# %%
temp_df = df2[df2['model'] == 'itel zeno 10']
df2.loc[temp_df.index , 'processor_name'] = 'unisoc t603'

# %%
df2[df2['num_cores'].isna()]
temp_df = df2[df2['model'] == 'lava o3 (3gb ram + 64gb)']
df2.loc[temp_df.index , 'processor_name'] = 'unisoc 9863a'

# %%
temp_df = df2[df2['model'] == 'lava o3']
df2.loc[temp_df.index , 'processor_name'] = 'unisoc 9863a'

# %%
df2[df2['num_cores'].isna()]
# Out:
#     brand_name                          model  price  rating  has_ir_blaster  \
# 682       itel  itel zeno 10 (4gb ram + 64gb)   5899    56.0               0
# 689       itel                   itel zeno 10   5999    55.0               0
# 695       lava       lava o3 (3gb ram + 64gb)   5799    55.0               0
# 857       lava                        lava o3   5899    57.0               0
#
#      has_5g  has_nfc processor_name processor_brand num_cores processor_speed  \
# 682       0        0    unisoc t603            octa       NaN             NaN
# 689       0        0    unisoc t603            octa       NaN             NaN
# 695       0        0   unisoc 9863a            octa       NaN             NaN
# 857       0        0   unisoc 9863a            octa       NaN             NaN
#
#           Ram         storage        battery_mAh    v_fast_charnging  \
# 682  4 GB RAM   64 GB inbuilt  5000 mAh Battery        Fast Charging
# ...

# %%
temp_df = df2[df2['Ram'].str.contains('inbuilt')]
df2.loc[temp_df.index , 'storage'] = temp_df['Ram']

df2[df2['Ram'].str.contains('inbuilt')]
# Out:
#     brand_name                         model   price  rating  has_ir_blaster  \
# 259      apple          apple iphone 16 plus   81900     NaN               0
# 470      apple  apple iphone 16 plus (256gb)   92900     NaN               0
# 728      apple  apple iphone 16 plus (512gb)  114900     NaN               0
#
#      has_5g  has_nfc processor_name processor_brand  num_cores  \
# 259       1        1     bionic a18          bionic  hexa core
# 470       1        1     bionic a18          bionic  hexa core
# 728       1        1     bionic a18          bionic  hexa core
#
#          processor_speed             Ram         storage        battery_mAh  \
# 259   4.04 GHz Processor  128 GB inbuilt  128 GB inbuilt  4674 mAh Battery
# 470   4.04 GHz Processor  256 GB inbuilt  256 GB inbuilt  4674 mAh Battery
# 728   4.04 GHz Processor  512 GB inbuilt  512 GB inbuilt  4674 mAh Battery
#
#     v_fast_charnging display_size display_speed  \
# ...

# %%
temp_df = df2[df2['model'].str.contains('apple iphone 16 plus')]
df2.loc[temp_df.index , 'Ram'] = '8 GB RAM'

# %%
temp_df = df2[df2['model'].str.contains('apple iphone 16 plus (256gb)')]
df2.loc[temp_df.index , 'Ram'] = '8 GB RAM'
# Out:
# /tmp/ipython-input-1687305630.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   temp_df = df2[df2['model'].str.contains('apple iphone 16 plus (256gb)')]

# %%
temp_df = df2[df2['model'].str.contains('apple iphone 16 plus (512gb)')]
df2.loc[temp_df.index , 'Ram'] = '8 GB RAM'
# Out:
# /tmp/ipython-input-3921882846.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   temp_df = df2[df2['model'].str.contains('apple iphone 16 plus (512gb)')]

# %%
df2['Ram'] = df2['Ram'].str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-1907630076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Ram'] = df2['Ram'].str.split(' ').str.get(0)

# %%
df2['Ram'] = df2['Ram'].str.replace('GB' , '')
# Out:
# /tmp/ipython-input-3372103376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Ram'] = df2['Ram'].str.replace('GB' , '')

# %%
df2['storage'] = df2['storage'].str.strip().str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-325541515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['storage'] = df2['storage'].str.strip().str.split(' ').str.get(0)

# %%
df2['storage'] = df2['storage'].str.replace('GB' , '')
# Out:
# /tmp/ipython-input-1919790052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['storage'] = df2['storage'].str.replace('GB' , '')

# %%
df2['storage'].value_counts()
# Out:
# storage
# 128     401
# 256     283
# 512      77
# 64       75
# 1 TB     10
# 32        5
# 16        1
# Name: count, dtype: int64

# %%
df2['storage'] = df2['storage'].str.replace('1 TB' , '1000')
# Out:
# /tmp/ipython-input-1783183032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['storage'] = df2['storage'].str.replace('1 TB' , '1000')

# %%
df2['storage'].value_counts()
# Out:
# storage
# 128     401
# 256     283
# 512      77
# 64       75
# 1000     10
# 32        5
# 16        1
# Name: count, dtype: int64

# %%
temp_df = df2[df2['model'] == 'realme p4 pro 5g']
df2.loc[temp_df.index , 'processor_speed'] = '2.8 GHz'
df2[df2['model'] == 'realme p4 pro 5g']
# Out:
#   brand_name             model  price  rating  has_ir_blaster  has_5g  \
# 2     realme  realme p4 pro 5g  24999    73.0               1       1
#
#    has_nfc      processor_name processor_brand  num_cores processor_speed Ram  \
# 2        0  snapdragon 7 gen 4      snapdragon  octa core         2.8 GHz  8
#
#   storage        battery_mAh    v_fast_charnging display_size  \
# 2    128   7000 mAh Battery    80W Fast Charging   6.8 inches
#
#                      display_speed       pixel_size                front  \
# 2   144 Hz Display with Punch Hole   1280 x 2800 px   50 MP Front Camera
#
#                rear_camera extended_memory os_system os_version
# 2  50 MP + 8 MP Dual Rear                0   android        v15

# %%
df2[df2['processor_speed'].isna()]
temp_df = df2[df2['model'] == 'google pixel 10 pro']
df2.loc[temp_df.index , 'processor_speed'] = '3.78 GHz'
df2[df2['model'] == 'google pixel 10 pro']
# Out:
#    brand_name                model   price  rating  has_ir_blaster  has_5g  \
# 28     google  google pixel 10 pro  109999     NaN               0       1
#
#     has_nfc processor_name processor_brand  num_cores processor_speed  Ram  \
# 28        1      tensor g5          tensor  octa core        3.78 GHz  16
#
#    storage        battery_mAh    v_fast_charnging display_size  \
# 28    256   4870 mAh Battery    30W Fast Charging   6.3 inches
#
#                       display_speed       pixel_size                front  \
# 28   120 Hz Display with Punch Hole   1280 x 2856 px   42 MP Front Camera
#
#                            rear_camera extended_memory os_system os_version
# 28  50 MP + 48 MP + 48 MP Triple Rear                0   android        v16

# %%
df2[df2['processor_speed'].isna()]
temp_df = df2[df2['model'] == 'google pixel 10']
df2.loc[temp_df.index , 'processor_speed'] = '3.78 GHz'
df2[df2['model'] == 'google pixel 10']
# Out:
#    brand_name            model  price  rating  has_ir_blaster  has_5g  \
# 66     google  google pixel 10  79999    79.0               0       1
#
#     has_nfc processor_name processor_brand  num_cores processor_speed  Ram  \
# 66        1      tensor g5          tensor  octa core        3.78 GHz  12
#
#    storage        battery_mAh    v_fast_charnging display_size  \
# 66    256   4970 mAh Battery    30W Fast Charging   6.3 inches
#
#                       display_speed       pixel_size                  front  \
# 66   120 Hz Display with Punch Hole   1080 x 2424 px   10.5 MP Front Camera
#
#                              rear_camera extended_memory os_system os_version
# 66  48 MP + 13 MP + 10.8 MP Triple Rear                0   android        v16

# %%
df2[df2['processor_speed'].isna()]
temp_df = df2[df2['model'] == 'realme 15 5g']
df2.loc[temp_df.index , 'processor_speed'] = '2.5 GHz'
df2[df2['model'] == 'realme 15 5g']
# Out:
#    brand_name         model  price  rating  has_ir_blaster  has_5g  has_nfc  \
# 79     realme  realme 15 5g  23999    74.0               0       1        0
#
#          processor_name processor_brand  num_cores processor_speed Ram  \
# 79  dimensity 7300 plus       dimensity  octa core         2.5 GHz  8
#
#    storage        battery_mAh    v_fast_charnging display_size  \
# 79    128   7000 mAh Battery    80W Fast Charging   6.8 inches
#
#                       display_speed       pixel_size                front  \
# 79   144 Hz Display with Punch Hole   1280 x 2800 px   50 MP Front Camera
#
#                 rear_camera extended_memory os_system os_version
# 79  50 MP + 8 MP Dual Rear                0   android        v15

# %%
df2[df2['processor_speed'].isna()]
# 2.2 GHz
temp_df = df2[df2['model'] == 'realme p4 pro 5g (12gb ram + 256gb)']
df2.loc[temp_df.index , 'processor_speed'] = '2.2 GHz'
df2[df2['model'] == 'realme p4 pro 5g (12gb ram + 256gb)']
# Out:
#    brand_name                                model  price  rating  \
# 93     realme  realme p4 pro 5g (12gb ram + 256gb)  28999    75.0
#
#     has_ir_blaster  has_5g  has_nfc      processor_name processor_brand  \
# 93               1       1        0  snapdragon 7 gen 4      snapdragon
#
#     num_cores processor_speed  Ram storage        battery_mAh  \
# 93  octa core         2.2 GHz  12     256   7000 mAh Battery
#
#       v_fast_charnging display_size                    display_speed  \
# 93   80W Fast Charging   6.8 inches   144 Hz Display with Punch Hole
#
#          pixel_size                front              rear_camera  \
# 93   1280 x 2800 px   50 MP Front Camera  50 MP + 8 MP Dual Rear
#
#    extended_memory os_system os_version
# 93               0   android        v15

# %%
df2[df2['processor_speed'].isna()]
# 2.3 GHz
temp_df = df2[df2['model'] == 'ai+ nova 5g']
df2.loc[temp_df.index , 'processor_speed'] = '2.2 GHz'
df2[df2['model'] == 'ai+ nova 5g']
# Out:
#     brand_name        model  price  rating  has_ir_blaster  has_5g  has_nfc  \
# 166        ai+  ai+ nova 5g   8499    67.0               0       1        0
#
#     processor_name processor_brand  num_cores processor_speed Ram storage  \
# 166   unisoc t8200          unisoc  octa core         2.2 GHz  6     128
#
#            battery_mAh    v_fast_charnging display_size  \
# 166  5000 mAh Battery    18W Fast Charging  6.75 inches
#
#                        display_speed      pixel_size               front  \
# 166   120 Hz Display with Punch Hole   720 x 1600 px   5 MP Front Camera
#
#           rear_camera extended_memory os_system os_version
# 166  50 MP Dual Rear             1 TB   android        v15

# %%
df2[df2['processor_speed'].isna()]
temp_df = df2[df2['model'] == 'realme 15 5g (8gb ram + 256gb)']
df2.loc[temp_df.index , 'processor_speed'] = '2.4 GHz'

# %%
df2[df2['processor_speed'].isna()]
temp_df = df2[df2['model'] == 'ai+ nova 5g (8gb ram + 128gb)']
df2.loc[temp_df.index , 'processor_speed'] = '2.1 GHz'
df2[df2['model'] == 'realme 15 5g (8gb ram + 256gb)']
# Out:
#     brand_name                           model  price  rating  has_ir_blaster  \
# 318     realme  realme 15 5g (8gb ram + 256gb)  27999    75.0               0
#
#      has_5g  has_nfc       processor_name processor_brand  num_cores  \
# 318       1        0  dimensity 7300 plus       dimensity  octa core
#
#     processor_speed Ram storage        battery_mAh    v_fast_charnging  \
# 318         2.4 GHz  8     256   7000 mAh Battery    80W Fast Charging
#
#     display_size                    display_speed       pixel_size  \
# 318   6.8 inches   144 Hz Display with Punch Hole   1280 x 2800 px
#
#                    front              rear_camera extended_memory os_system  \
# 318   50 MP Front Camera  50 MP + 8 MP Dual Rear                0   android
#
#     os_version
# 318        v15

# %%
df2['processor_speed'] = df2['processor_speed'].str.replace('Processor' , '')
# Out:
# /tmp/ipython-input-1207547225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_speed'] = df2['processor_speed'].str.replace('Processor' , '')

# %%
df2['processor_speed'] = df2['processor_speed'].str.replace('GHz' , '')
df2['processor_speed'] = df2['processor_speed'].str.replace('MHz' , '')
# Out:
# /tmp/ipython-input-1068584970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_speed'] = df2['processor_speed'].str.replace('GHz' , '')
# /tmp/ipython-input-1068584970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_speed'] = df2['processor_speed'].str.replace('MHz' , '')

# %%
df2['processor_speed'].value_counts()
# Out:
# processor_speed
#  2.4       185
#  2.2       109
#  2.5       102
#  2          37
#  2.6        35
#  1.8        33
#  3          32
#  3.2        31
#  2.8        29
#  3.35       26
#  2.3        22
#  2.63       20
#  3.3        15
#  3.25       14
#  3.1        14
#  1.6        14
#  4.47       13
#  4.32       11
#  2.7         9
#  4.04        9
#  4.05        7
#  3.36        6
#  2.85        6
#  3.63        6
#  3.46        5
#  3.22        4
#  3.4         4
#  2.9         4
#  3.39        3
#  1.82        3
#  3.11        2
#  3.05        2
# 3.78         2
#  2.96        2
# 2.2          2
#  2.05        2
#  2.84        2
#  2.1         2
# 2.8          1
# 2.5          1
# 2.1          1
# 2.4          1
#  2.26        1
# 2.3          1
#  512         1
#  3.78        1
#  2.91        1
# Name: count, dtype: int64

# %%
df2['processor_speed'] = df2['processor_speed'].str.replace('512' , '0.512')
# Out:
# /tmp/ipython-input-4056152297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['processor_speed'] = df2['processor_speed'].str.replace('512' , '0.512')

# %%
df2['battery_mAh'] = df2['battery_mAh'].str.replace('mAh Battery' , '')
# Out:
# /tmp/ipython-input-1336588418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['battery_mAh'] = df2['battery_mAh'].str.replace('mAh Battery' , '')

# %%
df2['v_fast_charnging'] = df2['v_fast_charnging'].fillna(0)
# Out:
# /tmp/ipython-input-835828780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['v_fast_charnging'] = df2['v_fast_charnging'].fillna(0)

# %%
df2['v_fast_charnging'] = df2['v_fast_charnging'].str.strip()
df2[df2['v_fast_charnging'] == 'Fast Charging']['model'].value_counts()
# Out:
# /tmp/ipython-input-314752405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['v_fast_charnging'] = df2['v_fast_charnging'].str.strip()
# model
# apple iphone 14 plus                    2
# apple iphone 16                         1
# apple iphone 16 pro max                 1
# google pixel 8a                         1
# apple iphone 13                         1
# apple iphone 15                         1
# apple iphone 16 pro                     1
# apple iphone 16e                        1
# apple iphone 16 plus                    1
# apple iphone 15 plus                    1
# motorola moto g62 (8gb ram + 128gb)     1
# lava storm lite 5g                      1
# apple iphone 16 pro max (1tb)           1
# ...

# %%
fast_chanrging = df2['v_fast_charnging'].str.contains('Fast Charging')

# %%
df2['display_size'] = df2['display_size'].str.replace('inches' , '')
# Out:
# /tmp/ipython-input-84602922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['display_size'] = df2['display_size'].str.replace('inches' , '')

# %%
df2['display_speed'] = df2['display_speed'].str.strip().str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-4244615887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['display_speed'] = df2['display_speed'].str.strip().str.split(' ').str.get(0)

# %%
df2['front'] = df2['front'].str.strip()
# Out:
# /tmp/ipython-input-2220776349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['front'] = df2['front'].str.strip()

# %%
df2['front'] = df2['front'].str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-2751490702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['front'] = df2['front'].str.split(' ').str.get(0)

# %%
df2['front'] = df2['front'].str.replace('MP' , '')
# Out:
# /tmp/ipython-input-3526257603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['front'] = df2['front'].str.replace('MP' , '')

# %%
df2['rear_main_camera'] = df2['rear_camera'].str.split(' ').str.get(0)
# Out:
# /tmp/ipython-input-892447952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['rear_main_camera'] = df2['rear_camera'].str.split(' ').str.get(0)

# %%
rear_camera = df2['rear_main_camera'].str.replace('MP' , '')

# %%
df1.insert(27 , 'main_rear_camera' , rear_camera)

# %%
df2.drop(columns=['rear_main_camera'] , inplace = True)
# Out:
# /tmp/ipython-input-401679739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['rear_main_camera'] , inplace = True)

# %%
df2['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                       415
# 1 TB                    242
# 2 TB                    101
# Memory Card (Hybrid)     38
# Not Specified            29
# 1.5 TB                   11
# 256 GB                    9
# 512 GB                    7
# Name: count, dtype: int64

# %%
df2['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                       415
# 1 TB                    242
# 2 TB                    101
# Memory Card (Hybrid)     38
# Not Specified            29
# 1.5 TB                   11
# 256 GB                    9
# 512 GB                    7
# Name: count, dtype: int64

# %%
df2['extended_memory'].value_counts( )
# Out:
# extended_memory
# 0                       415
# 1 TB                    242
# 2 TB                    101
# Memory Card (Hybrid)     38
# Not Specified            29
# 1.5 TB                   11
# 256 GB                    9
# 512 GB                    7
# Name: count, dtype: int64

# %%
def change(text):
    keywords = ['1 TB', '2 TB', '1.5 TB', '256 GB', '512 GB', 'Memory Card (Hybrid)']
    if any(word in text for word in keywords):
        return 1
    else:
        return 0

# %%
fst_charging = df2['v_fast_charnging'].str.split(' ').str.get(0).str.replace('W' , '')

# %%
df2.insert(15 , 'fast_charging' , fst_charging)

# %%
df2
# Out:
#      brand_name                       model  price  rating  has_ir_blaster  \
# 0          oppo          oppo k13 turbo pro  37999     NaN               1
# 1          vivo                 vivo v60 5g  36999     NaN               1
# 2        realme            realme p4 pro 5g  24999    73.0               1
# 3          lava          lava play ultra 5g  14999    79.0               0
# 4        realme                realme p4 5g  18499    77.0               1
# ...         ...                         ...    ...     ...             ...
# 1013       vivo                   vivo v29e  26999     NaN               0
# 1014    samsung       samsung galaxy f34 5g  19999     NaN               0
# 1015       vivo                    vivo y18  10599    70.0               0
# 1017       oppo         oppo reno 11 pro 5g  30900     NaN               1
# 1018       poco  poco f5 (12gb ram + 256gb)  33999     NaN               1
#
# ...

# %%
df.head(5)
# Out:
#    index               model    price  rating  \
# 0      2  Oppo K13 Turbo Pro  ₹37,999     NaN
# 1      3         Vivo V60 5G  ₹36,999     NaN
# 2      4    Realme P4 Pro 5G  ₹24,999    73.0
# 3      5  Lava Play Ultra 5G  ₹14,999    79.0
# 4      6        Realme P4 5G  ₹18,499    77.0
#
#                                                  sim  \
# 0     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3           Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 4     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                            processor  \
# 0   Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1    Snapdragon 7 Gen4, Octa Core, 2.8 GHz Processor
# 2            Snapdragon 7 Gen 4, Octa Core Processor
# 3       Dimensity 7300, Octa Core, 2.5 GHz Processor
# 4  Dimensity 7400 Ultra, Octa Core, 2.6 GHz Proce...
#
# ...

# %%
df2.to_csv('smartphone_clean2')

# %%
df2.rename(columns={
    'num_cores': 'cpu_cores',
    'processor_speed': 'cpu_speed_GHz',
    'Ram': 'ram_GB',
    'storage': 'storage_GB',
    'v_fast_charnging': 'fast_charging_support',
    'fast_charging': 'fast_charging_watt',
    'display_size': 'display_size_inches',
    'display_speed': 'display_refresh_rate_Hz',
    'pixel_size': 'display_ppi',
    'front': 'front_camera_MP',
    'rear_camera': 'rear_camera_MP',
    'extended_memory': 'memory_expandable_GB',
    'os_system': 'os_name'
} , inplace=True)
# Out:
# /tmp/ipython-input-4140845245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={

# %%
df2.drop(columns='fast_charging_support' , inplace=True)
# Out:
# /tmp/ipython-input-1079980301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns='fast_charging_support' , inplace=True)

# %%
df2.to_csv('smartphone_clean2.csv')

# %%
df2.to_excel('smart_phone.xlsx' , index=False)
